# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
num_points = 1000
x_data = []
y_data = []

# %%
for i in range(num_points):
    x = np.random.normal(0.0, 0.55)
    y = 0.3 + x * 0.1 + np.random.normal(0.0, 0.03)

    x_data.append(x)
    y_data.append(y)

# %%
plt.clf()
plt.title("Linear Regression")
plt.plot(x_data, y_data, 'ro', label='True Data', alpha=0.5)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\go2th\Miniconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\go2th\Miniconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
theta = np.array([random.random(), random.random()])

# %%
data_cnt = len(x_data)
print(data_cnt)
# Out:
# 1000

# %%
lr = 0.03
total_epoch = 200

# %%
for i in range(total_epoch):
    theta_0 = theta[0]
    theta_1 = theta[1]
    
    # cost - loss - MSE
    MSE = sum([(y - theta_0 - theta_1 * x ) ** 2 for x,y in zip(x_data, y_data)]) / data_cnt
    if (i + 1) % 10 == 0:
        print('MSE = ', MSE)
    
    # theta0 gradient    
    err_lst=[]
    for x,y in zip(x_data, y_data):
        err_lst.append(y - theta_0 - theta_1 * x)
    theta_0_grad = (-2 / data_cnt) * sum(err_lst)
    err_lst = []
    
    # theta1 gradient
    for x, y in zip(x_data, y_data):
        err_lst.append((y - theta_0 - (theta_1 * x)) * x)
    theta_1_grad = (-2 / data_cnt) * sum(err_lst)
    
    # gradient descent
    theta[0] = theta[0] - lr * theta_0_grad
    theta[1] = theta[1] - lr * theta_1_grad
# Out:
# MSE =  0.10135096087177527
# MSE =  0.030037817689279083
# MSE =  0.009351014605638718
# MSE =  0.0033499820593360812
# MSE =  0.0016090601640581985
# MSE =  0.0011039555965765546
# MSE =  0.0009573677911891101
# MSE =  0.0009147997574071315
# MSE =  0.0009024203144220163
# MSE =  0.0008988079119569562
# MSE =  0.0008977454367108706
# MSE =  0.0008974272757688155
# MSE =  0.0008973281868839438
# MSE =  0.0008972948042124998
# MSE =  0.0008972819543641166
# MSE =  0.0008972760658774882
# MSE =  0.0008972728828151698
# MSE =  0.0008972709528017312
# MSE =  0.0008972697058696746
# MSE =  0.0008972688752174855

# %%
predicted = [s * theta[1] + theta[0] for s in x_data]

plt.clf()
plt.title("Linear Regression")
plt.plot(x_data, y_data, 'ro', label='True Data', alpha=0.5)
plt.plot(x_data, predicted, '--', label='Predictions', alpha=0.5)
plt.legend(loc='best')
plt.show()

# %%
print("theta_0 = {}, theta_1 = {}".format(theta[0], theta[1]))
print("accuracy: theta_0 = {}, theta_1 = {}".
      format( 0.3 / theta[0], 0.1 / theta[1] ))
# Out:
# theta_0 = 0.2999496531755712, theta_1 = 0.10032015707149912
# accuracy: theta_0 = 1.0001678509172982, theta_1 = 0.9968086466285042
